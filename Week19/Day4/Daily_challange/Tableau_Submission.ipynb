# %% [markdown]
# # Inventory Analysis in Tableau — Submission
#
# **Primary Tableau workbook:**
#
# https://raw.githubusercontent.com/samslotin1/DI_Bootcamp/main/Week19/Day4/Daily_challange/Daily_Challenge.twb
#
# GitHub view:
#
# https://github.com/samslotin1/DI_Bootcamp/blob/main/Week19/Day4/Daily_challange/Daily_Challenge.twb

# %%
import requests
from IPython.display import FileLink, display

url = 'https://raw.githubusercontent.com/samslotin1/DI_Bootcamp/main/Week19/Day4/Daily_challange/Daily_Challenge.twb'
response = requests.get(url)
response.raise_for_status()
path = '/content/Daily_Challenge.twb'
with open(path, 'wb') as f:
    f.write(response.content)

print(f'Tableau workbook downloaded: {len(response.content):,} bytes')
display(FileLink(path))

# %% [markdown]
# ## Submission contents
#
# - Tableau workbook: `Daily_Challenge.twb`
# - Project: Inventory Analysis in Tableau
# - Workbook includes inventory turnover analysis, ABC classification, and an interactive dashboard.
