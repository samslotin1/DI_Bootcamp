# %% [markdown]
# # Inventory Analysis in Tableau — Submission
#
# This notebook is a submission wrapper for the Tableau assignment.
#
# Tableau workbook on GitHub:
#
# [Daily_Challenge.twb](https://github.com/samslotin1/DI_Bootcamp/blob/main/Week19/Day4/Daily_challange/Daily_Challenge.twb)
