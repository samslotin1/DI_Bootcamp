# %% [markdown]
# # Week 19 - Day 2 Tableau Assignment
#
# This notebook is the submission entry point for the Tableau exercises.
#
# The completed Tableau workbook is included in the same folder as `week19day2.twb`.
#
# Exercises completed:
# - Basic Scatter Plot
# - Enhanced Scatter Plot with Profit Ratio
# - Customer Ranking Bar Chart
# - Region-wise Profit Analysis
# - Interactive Dashboard
# - Filter and Highlight Actions
